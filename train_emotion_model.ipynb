# %% [markdown]
# # 감정 분류 모델 학습 (Google Colab)
#
# **목표**: 100 Epochs로 78%+ 정확도 달성
# - 데이터: 41,387개
# - 모델: KLUE-BERT
# - GPU: T4

# %%
# Step 1: GPU 확인
# !nvidia-smi
# Out:
# Tue Oct 28 11:34:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Step 2: 저장소 클론
# !git clone https://github.com/gijung2/chatbot.git
# %cd chatbot
# Out:
# Cloning into 'chatbot'...
# remote: Enumerating objects: 127, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 127 (delta 29), reused 114 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (127/127), 14.81 MiB | 13.60 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# /content/chatbot

# %%
# Step 3: 패키지 설치
# !pip install transformers torch pandas scikit-learn matplotlib seaborn tqdm
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)

# %%
# Step 4: 학습 시작 (10 epochs 테스트 - 2~3시간)
# !python training/main_kfold.py \
  --data_path data/processed/emotion_corpus_full.csv \
  --model_name klue/bert-base \
  --k_folds 5 \
  --epochs 10 \
  --batch_size 32
# Out:
# INFO:__main__:🌱 시드 설정: 42
# INFO:__main__:
# ================================================================================
# INFO:__main__:⚙️ K-Fold Cross Validation 설정
# INFO:__main__:================================================================================
# INFO:__main__:   - data_path: data/processed/emotion_corpus_full.csv
# INFO:__main__:   - text_column: text
# INFO:__main__:   - label_column: label_id
# INFO:__main__:   - k_folds: 5
# INFO:__main__:   - model_name: klue/bert-base
# INFO:__main__:   - num_labels: 5
# INFO:__main__:   - dropout_rate: 0.3
# INFO:__main__:   - freeze_bert: False
# INFO:__main__:   - batch_size: 32
# INFO:__main__:   - epochs: 10
# INFO:__main__:   - learning_rate: 2e-05
# INFO:__main__:   - max_length: 128
# INFO:__main__:   - warmup_steps: 0
# INFO:__main__:   - max_grad_norm: 1.0
# INFO:__main__:   - early_stopping_patience: 3
# INFO:__main__:   - output_dir: checkpoints_kfold
# INFO:__main__:   - save_all_folds: False
# INFO:__main__:   - num_workers: 0
# INFO:__main__:   - seed: 42
# INFO:__main__:
# 🖥️ 디바이스: cuda
# INFO:__main__:   - GPU: Tesla T4
# INFO:__main__:   - CUDA 버전: 12.6
# INFO:__main__:
# ================================================================================
# INFO:__main__:📂 전체 데이터 로드
# INFO:__main__:================================================================================
# INFO:__main__:   - 경로: data/processed/emotion_corpus_full.csv
# INFO:__main__:✅ 데이터 로드 완료: 41,387 samples
# INFO:__main__:   - 컬럼: ['text', 'emotion', 'label_id', 'emotion_code']
# INFO:__main__:
# 📊 클래스 분포:
# INFO:__main__:   - joy (id=0): 2,052 (5.0%)
# INFO:__main__:   - sad (id=1): 10,983 (26.5%)
# INFO:__main__:   - anxiety (id=2): 17,534 (42.4%)
# INFO:__main__:   - anger (id=3): 9,039 (21.8%)
# INFO:__main__:   - neutral (id=4): 1,779 (4.3%)
# INFO:__main__:
# ================================================================================
# INFO:__main__:🔀 5-Fold Stratified 분할 생성
# INFO:__main__:================================================================================
# INFO:__main__:   Fold 1: Train=33,109, Val=8,278
# INFO:__main__:   Fold 2: Train=33,109, Val=8,278
# INFO:__main__:   Fold 3: Train=33,110, Val=8,277
# INFO:__main__:   Fold 4: Train=33,110, Val=8,277
# INFO:__main__:   Fold 5: Train=33,110, Val=8,277
# INFO:__main__:
# ================================================================================
# INFO:__main__:🔤 토크나이저 로드
# INFO:__main__:================================================================================
# tokenizer_config.json: 100% 289/289 [00:00<00:00, 2.20MB/s]
# config.json: 100% 425/425 [00:00<00:00, 3.95MB/s]
# vocab.txt: 248kB [00:00, 4.10MB/s]
# tokenizer.json: 495kB [00:00, 11.5MB/s]
# special_tokens_map.json: 100% 125/125 [00:00<00:00, 1.30MB/s]
# INFO:__main__:✅ 토크나이저 로드 완료: klue/bert-base
# INFO:__main__:
# ================================================================================
# INFO:__main__:📊 Fold 1/5 학습 시작
# INFO:__main__:================================================================================
# INFO:__main__:✅ Train batches: 1035, Val batches: 259
# INFO:model:🤖 모델 로드: klue/bert-base
# 2025-10-28 11:35:05.691913: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761651305.711010    1201 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761651305.716824    1201 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761651305.731535    1201 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761651305.731559    1201 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761651305.731563    1201 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761651305.731567    1201 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-28 11:35:05.735931: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors: 100% 445M/445M [00:12<00:00, 34.4MB/s]
# INFO:model:✅ 모델 초기화 완료
# INFO:model:   - BERT hidden size: 768
# INFO:model:   - 클래스 수: 5
# INFO:model:   - Dropout: 0.3
# INFO:model:🔢 전체 파라미터: 110,621,189
# INFO:model:🔢 학습 가능 파라미터: 110,621,189 (100.00%)
# INFO:model:🖥️ 디바이스: cuda
# INFO:train:✅ Trainer 초기화 완료
# INFO:train:   - Learning rate: 2e-05
# INFO:train:   - Warmup steps: 0
# INFO:train:   - Max grad norm: 1.0
# INFO:train:🚀 학습 시작: 10 에폭
# INFO:train:
# ============================================================
# INFO:train:Epoch 1/10
# INFO:train:============================================================
# Training: 100% 1035/1035 [10:58<00:00,  1.57it/s, loss=0.8380]
# Validation: 100% 259/259 [00:56<00:00,  4.60it/s]
# INFO:train:
# 📊 Epoch 1 결과:
# INFO:train:   - Train Loss: 0.9890
# INFO:train:   - Val Loss: 0.9028
# INFO:train:   - Val Accuracy: 0.6024
# INFO:train:   - Val F1 (weighted): 0.5839
# INFO:train:   - Time: 715.01s
# INFO:train:
# 📈 클래스별 성능:
# INFO:train:   - joy: P=0.633, R=0.573, F1=0.602
# INFO:train:   - sad: P=0.631, R=0.399, F1=0.489
# INFO:train:   - anxiety: P=0.574, R=0.853, F1=0.686
# INFO:train:   - anger: P=0.732, R=0.407, F1=0.523
# INFO:train:   - neutral: P=0.493, R=0.419, F1=0.453
# INFO:train:💾 Best 모델 저장: checkpoints_kfold/fold1_model_20251028_113501.pt
# INFO:train:
# ============================================================
# INFO:train:Epoch 2/10
# INFO:train:============================================================
# Training: 100% 1035/1035 [11:02<00:00,  1.56it/s, loss=0.8426]
# Validation: 100% 259/259 [00:56<00:00,  4.60it/s]
# INFO:train:
# 📊 Epoch 2 결과:
# INFO:train:   - Train Loss: 0.8243
# INFO:train:   - Val Loss: 0.9121
# INFO:train:   - Val Accuracy: 0.6129
# INFO:train:   - Val F1 (weighted): 0.6079
# INFO:train:   - Time: 719.11s
# INFO:train:
# 📈 클래스별 성능:
# INFO:train:   - joy: P=0.622, R=0.685, F1=0.652
# INFO:train:   - sad: P=0.519, R=0.584, F1=0.550
# INFO:train:   - anxiety: P=0.639, R=0.734, F1=0.683
# INFO:train:   - anger: P=0.729, R=0.437, F1=0.546
# INFO:train:   - neutral: P=0.596, R=0.410, F1=0.486
# INFO:train:⏳ Early stopping counter: 1/3
# INFO:train:
# ============================================================
# INFO:train:Epoch 3/10
# INFO:train:============================================================
# Training: 100% 1035/1035 [11:01<00:00,  1.56it/s, loss=0.9454]
# Validation: 100% 259/259 [00:56<00:00,  4.60it/s]
# INFO:train:
# 📊 Epoch 3 결과:
# INFO:train:   - Train Loss: 0.6781
# INFO:train:   - Val Loss: 0.9792
# INFO:train:   - Val Accuracy: 0.6134
# INFO:train:   - Val F1 (weighted): 0.6049
# INFO:train:   - Time: 717.94s
# INFO:train:
# 📈 클래스별 성능:
# INFO:train:   - joy: P=0.645, R=0.629, F1=0.637
# INFO:train:   - sad: P=0.581, R=0.462, F1=0.515
# INFO:train:   - anxiety: P=0.620, R=0.780, F1=0.691
# INFO:train:   - anger: P=0.640, R=0.501, F1=0.562
# INFO:train:   - neutral: P=0.545, R=0.463, F1=0.501
# INFO:train:⏳ Early stopping counter: 2/3
# INFO:train:
# ============================================================
# INFO:train:Epoch 4/10
# INFO:train:============================================================
# Training: 100% 1035/1035 [11:01<00:00,  1.56it/s, loss=0.8060]
# Validation: 100% 259/259 [00:56<00:00,  4.60it/s]
# INFO:train:
# 📊 Epoch 4 결과:
# INFO:train:   - Train Loss: 0.5230
# INFO:train:   - Val Loss: 1.0653
# INFO:train:   - Val Accuracy: 0.5957
# INFO:train:   - Val F1 (weighted): 0.5967
# INFO:train:   - Time: 717.96s
# INFO:train:
# 📈 클래스별 성능:
# INFO:train:   - joy: P=0.668, R=0.593, F1=0.628
# INFO:train:   - sad: P=0.508, R=0.564, F1=0.535
# INFO:train:   - anxiety: P=0.665, R=0.642, F1=0.653
# INFO:train:   - anger: P=0.579, R=0.572, F1=0.576
# INFO:train:   - neutral: P=0.534, R=0.458, F1=0.493
# INFO:train:⏳ Early stopping counter: 3/3
# INFO:train:⛔ Early stopping at epoch 4
# INFO:train:
# ============================================================
# INFO:train:✅ 학습 완료!
# INFO:train:   - Best Val Loss: 0.9028
# INFO:train:============================================================
#
# INFO:__main__:
# 📊 Fold 1 결과:
# INFO:__main__:   - Best Epoch: 2
# INFO:__main__:   - Best Val Acc: 0.6129
# INFO:__main__:   - Best Val F1: 0.6079
# INFO:__main__:   - Best Val Loss: 0.9121
# INFO:__main__:
# ================================================================================
# INFO:__main__:📊 Fold 2/5 학습 시작
# INFO:__main__:================================================================================
# INFO:__main__:✅ Train batches: 1035, Val batches: 259
# INFO:model:🤖 모델 로드: klue/bert-base
# INFO:model:✅ 모델 초기화 완료
# INFO:model:   - BERT hidden size: 768
# INFO:model:   - 클래스 수: 5
# INFO:model:   - Dropout: 0.3
# INFO:model:🔢 전체 파라미터: 110,621,189
# INFO:model:🔢 학습 가능 파라미터: 110,621,189 (100.00%)
# INFO:model:🖥️ 디바이스: cuda
# INFO:train:✅ Trainer 초기화 완료
# INFO:train:   - Learning rate: 2e-05
# INFO:train:   - Warmup steps: 0
# INFO:train:   - Max grad norm: 1.0
# INFO:train:🚀 학습 시작: 10 에폭
# INFO:train:
# ============================================================
# INFO:train:Epoch 1/10
# INFO:train:============================================================
# Training: 100% 1035/1035 [11:00<00:00,  1.57it/s, loss=0.7708]
# Validation: 100% 259/259 [00:56<00:00,  4.61it/s]
# INFO:train:
# 📊 Epoch 1 결과:
# INFO:train:   - Train Loss: 0.9940
# INFO:train:   - Val Loss: 0.9276
# INFO:train:   - Val Accuracy: 0.6029
# INFO:train:   - Val F1 (weighted): 0.5908
# INFO:train:   - Time: 717.17s
# INFO:train:
# 📈 클래스별 성능:
# INFO:train:   - joy: P=0.512, R=0.754, F1=0.610
# INFO:train:   - sad: P=0.661, R=0.363, F1=0.469
# INFO:train:   - anxiety: P=0.633, R=0.742, F1=0.683
# INFO:train:   - anger: P=0.536, R=0.641, F1=0.584
# INFO:train:   - neutral: P=0.626, R=0.348, F1=0.448
# INFO:train:💾 Best 모델 저장: checkpoints_kfold/fold2_model_20251028_113501.pt
# INFO:train:
# ============================================================
# INFO:train:Epoch 2/10
# INFO:train:============================================================
# Training: 100% 1035/1035 [11:02<00:00,  1.56it/s, loss=0.8247]
# Validation: 100% 259/259 [00:56<00:00,  4.60it/s]
# INFO:train:
# 📊 Epoch 2 결과:
# INFO:train:   - Train Loss: 0.8312
# INFO:train:   - Val Loss: 0.9088
# INFO:train:   - Val Accuracy: 0.6149
# INFO:train:   - Val F1 (weighted): 0.6054
# INFO:train:   - Time: 718.57s
# INFO:train:
# 📈 클래스별 성능:
# INFO:train:   - joy: P=0.632, R=0.644, F1=0.638
# INFO:train:   - sad: P=0.645, R=0.418, F1=0.507
# INFO:train:   - anxiety: P=0.629, R=0.755, F1=0.687
# INFO:train:   - anger: P=0.554, R=0.630, F1=0.590
# INFO:train:   - neutral: P=0.706, R=0.337, F1=0.456
# INFO:train:💾 Best 모델 저장: checkpoints_kfold/fold2_model_20251028_113501.pt
# INFO:train:
# ============================================================
# INFO:train:Epoch 3/10
# INFO:train:============================================================
# Training: 100% 1035/1035 [11:02<00:00,  1.56it/s, loss=0.8240]
# Validation: 100% 259/259 [00:56<00:00,  4.59it/s]
# INFO:train:
# 📊 Epoch 3 결과:
# INFO:train:   - Train Loss: 0.6929
# INFO:train:   - Val Loss: 0.9478
# INFO:train:   - Val Accuracy: 0.6208
# INFO:train:   - Val F1 (weighted): 0.6155
# INFO:train:   - Time: 718.61s
# INFO:train:
# 📈 클래스별 성능:
# INFO:train:   - joy: P=0.640, R=0.654, F1=0.647
# INFO:train:   - sad: P=0.590, R=0.478, F1=0.529
# INFO:train:   - anxiety: P=0.642, R=0.744, F1=0.689
# INFO:train:   - anger: P=0.599, R=0.581, F1=0.590
# INFO:train:   - neutral: P=0.611, R=0.449, F1=0.518
# INFO:train:⏳ Early stopping counter: 1/3
# INFO:train:
# ============================================================
# INFO:train:Epoch 4/10
# INFO:train:============================================================
# Training: 100% 1035/1035 [11:01<00:00,  1.56it/s, loss=0.5114]
# Validation: 100% 259/259 [00:56<00:00,  4.61it/s]
# INFO:train:
# 📊 Epoch 4 결과:
# INFO:train:   - Train Loss: 0.5414
# INFO:train:   - Val Loss: 1.0349
# INFO:train:   - Val Accuracy: 0.6201
# INFO:train:   - Val F1 (weighted): 0.6150
# INFO:train:   - Time: 717.93s
# INFO:train:
# 📈 클래스별 성능:
# INFO:train:   - joy: P=0.596, R=0.651, F1=0.622
# INFO:train:   - sad: P=0.580, R=0.516, F1=0.546
# INFO:train:   - anxiety: P=0.644, R=0.749, F1=0.693
# INFO:train:   - anger: P=0.623, R=0.523, F1=0.568
# INFO:train:   - neutral: P=0.569, R=0.449, F1=0.502
# INFO:train:⏳ Early stopping counter: 2/3
# INFO:train:
# ============================================================
# INFO:train:Epoch 5/10
# INFO:train:============================================================
# Training: 100% 1035/1035 [11:02<00:00,  1.56it/s, loss=0.3403]
# Validation: 100% 259/259 [00:56<00:00,  4.60it/s]
# INFO:train:
# 📊 Epoch 5 결과:
# INFO:train:   - Train Loss: 0.3949
# INFO:train:   - Val Loss: 1.1879
# INFO:train:   - Val Accuracy: 0.6149
# INFO:train:   - Val F1 (weighted): 0.6125
# INFO:train:   - Time: 718.32s
# INFO:train:
# 📈 클래스별 성능:
# INFO:train:   - joy: P=0.631, R=0.639, F1=0.635
# INFO:train:   - sad: P=0.541, R=0.563, F1=0.552
# INFO:train:   - anxiety: P=0.652, R=0.713, F1=0.681
# INFO:train:   - anger: P=0.637, R=0.513, F1=0.569
# INFO:train:   - neutral: P=0.569, R=0.461, F1=0.509
# INFO:train:⏳ Early stopping counter: 3/3
# INFO:train:⛔ Early stopping at epoch 5
# INFO:train:
# ============================================================
# INFO:train:✅ 학습 완료!
# INFO:train:   - Best Val Loss: 0.9088
# INFO:train:============================================================
#
# INFO:__main__:
# 📊 Fold 2 결과:
# INFO:__main__:   - Best Epoch: 3
# INFO:__main__:   - Best Val Acc: 0.6208
# INFO:__main__:   - Best Val F1: 0.6155
# INFO:__main__:   - Best Val Loss: 0.9478
# INFO:__main__:
# ================================================================================
# INFO:__main__:📊 Fold 3/5 학습 시작
# INFO:__main__:================================================================================
# INFO:__main__:✅ Train batches: 1035, Val batches: 259
# INFO:model:🤖 모델 로드: klue/bert-base
# INFO:model:✅ 모델 초기화 완료
# INFO:model:   - BERT hidden size: 768
# INFO:model:   - 클래스 수: 5
# INFO:model:   - Dropout: 0.3
# INFO:model:🔢 전체 파라미터: 110,621,189
# INFO:model:🔢 학습 가능 파라미터: 110,621,189 (100.00%)
# INFO:model:🖥️ 디바이스: cuda
# INFO:train:✅ Trainer 초기화 완료
# INFO:train:   - Learning rate: 2e-05
# INFO:train:   - Warmup steps: 0
# INFO:train:   - Max grad norm: 1.0
# INFO:train:🚀 학습 시작: 10 에폭
# INFO:train:
# ============================================================
# INFO:train:Epoch 1/10
# INFO:train:============================================================
# Training:  53% 547/1035 [05:49<05:12,  1.56it/s, loss=1.0680]

# %%
# !python training/main_kfold.py \
  --data_path data/processed/emotion_corpus_full.csv \
  --model_name klue/bert-base \
  --k_folds 2 \
  --epochs 40 \
  --batch_size 32

# %%
# Step 6: 결과 확인
# !ls -lh checkpoints_kfold/

# %%
# Step 7: 모델 다운로드
# !zip -r model.zip checkpoints_kfold/
from google.colab import files
files.download('model.zip')
